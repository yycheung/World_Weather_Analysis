# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.

vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.loc[vacation_df['Country']=='US']
# Out:
#      City_ID            City Country  Max Temp      Current Description  \
# 3         11   Half Moon Bay      US     70.02                clear sky
# 24        59           Kapaa      US     82.11                clear sky
# 58       140            Hilo      US     82.13               few clouds
# 67       161    San Patricio      US     70.54          overcast clouds
# 72       172  Cape Canaveral      US     72.99            moderate rain
# 86       204          Lompoc      US     75.69                clear sky
# 104      252       Morro Bay      US     73.26                clear sky
# 160      419         Kahului      US     82.98                clear sky
# 161      420    Stephenville      US     73.49                clear sky
# 210      537         Brandon      US     75.99  light intensity drizzle
# 229      584           Houma      US     73.00         scattered clouds
# 265      667      Chowchilla      US     71.02                clear sky
# 266      668       Ewa Beach      US     84.15                clear sky
#
#          Lat       Lng                                         Hotel Name
# 3    37.4636 -122.4286                    The Ritz-Carlton, Half Moon Bay
# 24   22.0752 -159.3190                Sheraton Kauai Coconut Beach Resort
# 58   19.7297 -155.0900                                Hilo Hawaiian Hotel
# 67   28.0170  -97.5169                                 Motel 6 Sinton, TX
# 72   28.4058  -80.6048  Residence Inn by Marriott Cape Canaveral Cocoa...
# 86   34.6391 -120.4579           Holiday Inn Express Lompoc, an IHG Hotel
# 104  35.3658 -120.8499                                   Inn at Morro Bay
# 160  20.8947 -156.4700                                 Maui Seaside Hotel
# 161  32.2207  -98.2023     La Quinta Inn & Suites by Wyndham Stephenville
# 210  27.9378  -82.2859             Embassy Suites by Hilton Tampa Brandon
# 229  29.5958  -90.7195                        Courtyard by Marriott Houma
# 265  37.1230 -120.2602  Days Inn by Wyndham Chowchilla Gateway to Yose...
# 266  21.3156 -158.0072                                       Base Lodging

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
figure_layout = {
    'width': '800px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto',
    'zoom_level':1
}
fig = gmaps.figure(layout=figure_layout)

# Access maps with unique API key
gmaps.configure(api_key=g_key)
locations = vacation_df[["Lat", "Lng"]]

# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content=vacation_info)
# Add the layer to the map
fig.add_layer(markers)



# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City']=='Half Moon Bay']
vacation_end = vacation_df.loc[vacation_df['City']=='Half Moon Bay']
vacation_stop1 = vacation_df.loc[vacation_df['City']=='Morro Bay']
vacation_stop2 = vacation_df.loc[vacation_df['City']=='Cape Canaveral']
vacation_stop3 = vacation_df.loc[vacation_df['City']=='Chowchilla']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')
print(f'Stop 1: {stop1}, Stop 2: {stop2}, Stop 3: {stop3}')
# Out:
# Start: (37.4636, -122.4286), End: (37.4636, -122.4286)
# Stop 1: (35.3658, -120.8499), Stop 2: (28.4058, -80.6048), Stop 3: (37.123, -120.2602)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".


fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.


itinerary_df = pd.concat([vacation_start,vacation_stop1, vacation_stop2, vacation_stop3], ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0       11   Half Moon Bay      US     70.02           clear sky  37.4636
# 1      252       Morro Bay      US     73.26           clear sky  35.3658
# 2      172  Cape Canaveral      US     72.99       moderate rain  28.4058
# 3      667      Chowchilla      US     71.02           clear sky  37.1230
#
#         Lng                                         Hotel Name
# 0 -122.4286                    The Ritz-Carlton, Half Moon Bay
# 1 -120.8499                                   Inn at Morro Bay
# 2  -80.6048  Residence Inn by Marriott Cape Canaveral Cocoa...
# 3 -120.2602  Days Inn by Wyndham Chowchilla Gateway to Yose...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
figure_layout = {
    'width': '800px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto',
    'zoom_level':0.3
}
fig = gmaps.figure(layout=figure_layout)

# Access maps with unique API key
gmaps.configure(api_key=g_key)
locations = itinerary_df[["Lat", "Lng"]]

# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content=vacation_info)
# Add the layer to the map
fig.add_layer(markers)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
